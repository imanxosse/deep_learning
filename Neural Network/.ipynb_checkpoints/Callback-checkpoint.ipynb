# %% [markdown]
# # Callbacks

# %% [markdown]
# #### Check if training loss is less than 0.4

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline


class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('loss') < 0.4):
            print("\nReached 0.4 loss so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

(training_images, training_labels), (test_images, test_labels) =  tf.keras.datasets.fashion_mnist.load_data()

training_images = np.float32(training_images)
test_images = np.float32(test_images)
training_images /= 255.0
test_images /= 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=512, activation=tf.nn.relu),
  tf.keras.layers.Dense(units=10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(training_images, 
                    training_labels,
                    validation_split=0.1,
                    epochs=15, 
                    callbacks=[callbacks])

print('\n')

pd.DataFrame(history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.gca().set_ylim(0, 1)  
plt.legend(loc='best')
plt.show()
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/15
# 54000/54000 [==============================] - 7s 125us/sample - loss: 0.4834 - accuracy: 0.8283 - val_loss: 0.3933 - val_accuracy: 0.8568
# Epoch 2/15
# 53536/54000 [============================>.] - ETA: 0s - loss: 0.3650 - accuracy: 0.8666
# Reached 0.4 loss so cancelling training!
# 54000/54000 [==============================] - 5s 92us/sample - loss: 0.3652 - accuracy: 0.8666 - val_loss: 0.3533 - val_accuracy: 0.8698

# %% [markdown]
# <br>
#
# <br>
#
# #### Check if validation accuracy is greater than 0.88

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > 0.88):
            print("\nReached 88% validation accuracy so cancelling training!")
            self.model.stop_training = True


callbacks = myCallback()

(training_images, training_labels), (test_images, test_labels) =  tf.keras.datasets.fashion_mnist.load_data()

training_images = np.float32(training_images)
test_images = np.float32(test_images)
training_images /= 255.0
test_images /= 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=512, activation=tf.nn.relu),
  tf.keras.layers.Dense(units=10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(training_images, 
                    training_labels,
                    validation_split=0.1, 
                    epochs=15, 
                    callbacks=[callbacks])

print('\n')

pd.DataFrame(history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.gca().set_ylim(0, 1)  
plt.legend(loc='best')
plt.show()
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/15
# 54000/54000 [==============================] - 5s 88us/sample - loss: 0.4807 - accuracy: 0.8279 - val_loss: 0.3976 - val_accuracy: 0.8583
# Epoch 2/15
# 54000/54000 [==============================] - 5s 85us/sample - loss: 0.3674 - accuracy: 0.8653 - val_loss: 0.3596 - val_accuracy: 0.8717
# Epoch 3/15
# 54000/54000 [==============================] - 4s 82us/sample - loss: 0.3253 - accuracy: 0.8807 - val_loss: 0.3505 - val_accuracy: 0.8745
# Epoch 4/15
# 53440/54000 [============================>.] - ETA: 0s - loss: 0.3017 - accuracy: 0.8897
# Reached 88% validation accuracy so cancelling training!
# 54000/54000 [==============================] - 5s 87us/sample - loss: 0.3014 - accuracy: 0.8899 - val_loss: 0.3269 - val_accuracy: 0.8833

# %% [markdown]
# <br>
#
# <br>
#
# ---
